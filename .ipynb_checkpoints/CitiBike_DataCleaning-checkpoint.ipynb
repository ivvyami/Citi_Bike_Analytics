# %%
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# # Load Up Files

# %%
# File to Load (Remember to Change These)
file_to_load = "data/JC-201701-citibike-tripdata.csv"

# Read Purchasing File and store into Pandas data frame
cb_2017_01 = pd.read_csv(file_to_load)

#look at your data first!
cb_2017_01.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  \
# ...

# %%
# have list to rename all column names 

column_names = ["trip duration", 
                "start time", 
               "stop time", 
               "start station ID", 
               "start station name", 
               "start station latitude", 
               "start station longitude", 
               "end station ID", 
               "end station name", 
               "end station latitude", 
               "end station longitude", 
               "bike ID", 
               "user type", 
               "birth year",
               "gender"]

# %%
test = cb_2017_01

# %%
test.columns = column_names

# %%
test.columns
test.head()
test.shape
# Out:
# (12926, 15)

# %%
cb_2017_01.columns
# Out:
# Index(['trip duration', 'start time', 'stop time', 'start station ID',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station ID', 'end station name',
#        'end station latitude', 'end station longitude', 'bike ID', 'user type',
#        'birth year', 'gender'],
#       dtype='object')

# %% [markdown]
# ## Load up the rest

# %%
# File to Load (Remember to Change These)

#2017

feb_17 = "data/JC-201702-citibike-tripdata.csv"
march_17 = "data/JC-201703-citibike-tripdata.csv"
april_17 = "data/JC-201704-citibike-tripdata.csv"
may_17 = "data/JC-201705-citibike-tripdata.csv"
june_17 = "data/JC-201706-citibike-tripdata.csv"
july_17 = "data/JC-201707-citibike-tripdata.csv"
aug_17 = "data/JC-201708-citibike-tripdata.csv"
sep_17 = "data/JC-201709-citibike-tripdata.csv"
oct_17 = "data/JC-201710-citibike-tripdata.csv"
nov_17 = "data/JC-201711-citibike-tripdata.csv"
dec_17 = "data/JC-201712-citibike-tripdata.csv"
# Read Purchasing File and store into Pandas data frame
cb_2017_02 = pd.read_csv(feb_17)
cb_2017_03 = pd.read_csv(march_17)
cb_2017_04 = pd.read_csv(april_17)
cb_2017_05 = pd.read_csv(may_17)
cb_2017_06 = pd.read_csv(june_17)
cb_2017_07 = pd.read_csv(july_17)
cb_2017_08 = pd.read_csv(aug_17)
cb_2017_09 = pd.read_csv(sep_17)
cb_2017_10 = pd.read_csv(oct_17)
cb_2017_11 = pd.read_csv(nov_17)
cb_2017_12 = pd.read_csv(dec_17)


#2018
jan_18 = "data/JC-201801-citibike-tripdata.csv"
feb_18 = "data/JC-201802-citibike-tripdata.csv"
march_18 = "data/JC-201803-citibike-tripdata.csv"
april_18 = "data/JC-201804-citibike-tripdata.csv"
may_18 = "data/JC-201805-citibike-tripdata.csv"
june_18 = "data/JC-201806-citibike-tripdata.csv"
july_18 = "data/JC-201807-citibike-tripdata.csv"
aug_18 = "data/JC-201808-citibike-tripdata.csv"
sep_18 = "data/JC-201809-citibike-tripdata.csv"
oct_18 = "data/JC-201810-citibike-tripdata.csv"
nov_18 = "data/JC-201811-citibike-tripdata.csv"
dec_18 = "data/JC-201812-citibike-tripdata.csv"
# Read Purchasing File and store into Pandas data frame
cb_2017_02 = pd.read_csv(feb_17)
cb_2017_03 = pd.read_csv(march_17)
cb_2017_04 = pd.read_csv(april_17)
cb_2017_05 = pd.read_csv(may_17)
cb_2017_06 = pd.read_csv(june_17)
cb_2017_07 = pd.read_csv(july_17)
cb_2017_08 = pd.read_csv(aug_17)
cb_2017_09 = pd.read_csv(sep_17)
cb_2017_10 = pd.read_csv(oct_17)
cb_2017_11 = pd.read_csv(nov_17)
cb_2017_12 = pd.read_csv(dec_17)

# %%
# get data file names
path =r'C:\Users\ivvya\Desktop\Bootcamp\HW\Citi_Bike_Analytics\data'
filenames = glob.glob(path + "/*.csv")

cityBike_df = []
for filename in filenames:
    df = pd.read_csv(filename, index_col=None, header=0)
    df.columns = column_names
    cityBike_df.append(df)
    

# Concatenate all data into one DataFrame
cityBike_big = pd.concat(cityBike_df, ignore_index=True)

# %%
cityBike_big.shape
# Out:
# (960989, 15)

# %%
cityBike_big.head()
# Out:
#    trip duration           start time            stop time  start station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station ID     end station name  end station latitude  \
# ...
